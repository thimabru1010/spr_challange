# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# csv_path = 'data/medidas_SPR_9s_final.csv'
csv_path = '/home/thiago/IDOR/SPR_HeadCT_Age_Prediction_Challenge/spr_challange/data/submission.csv'
df = pd.read_csv(csv_path, sep=',')

# %%
print(df.head(10))
# Out:
#    StudyID   Age
# 0     2800  41.0
# 1     2940  29.0
# 2     2850  44.0
# 3     2807  58.0
# 4     2908  56.0
# 5     2884  30.0
# 6     2810  39.0
# 7     2878  54.0
# 8     2859  38.0
# 9     2795  29.0

# %%
df['age_round'] = df['Age'].round()
print(df.head(10))
# Out:
#    StudyID   Age  age_round
# 0     2800  41.0       41.0
# 1     2940  29.0       29.0
# 2     2850  44.0       44.0
# 3     2807  58.0       58.0
# 4     2908  56.0       56.0
# 5     2884  30.0       30.0
# 6     2810  39.0       39.0
# 7     2878  54.0       54.0
# 8     2859  38.0       38.0
# 9     2795  29.0       29.0

# %%
plt.hist(df['age_round'], bins=20)
plt.tight_layout()
plt.show()

# %%
# plt.plot(df['age'], df['fluid_ratio'])
fig = plt.figure()
plt.bar(df['age'], df['fluid_ratio'])
plt.tight_layout()
plt.show()
fig.savefig('data/age_fluid_ratio.png', dpi=300)

# %%
plt.bar(df['age'], df['mass_ratio'])
plt.tight_layout()
plt.show()

# %%
plt.bar(df['age'], df['calc_ratio'])
plt.tight_layout()
plt.show()
