# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_path = 'data/medidas_SPR_9s_final.csv'
df = pd.read_csv(csv_path, sep=',')

# %%
print(df.head(10))
# Out:
#      ID  sex  mass_ratio  fluid_ratio  fm_ratio  calc_ratio  age
# 0  2457    1    0.823673     0.145792  0.177002    0.030535   87
# 1  2401    0    0.916357     0.047605  0.051951    0.036037   55
# 2  2529    1    0.802413     0.166659  0.207697    0.030929   52
# 3  2469    0    0.749300     0.223864  0.298765    0.026836   67
# 4  2350    0    0.894061     0.072796  0.081422    0.033142   37
# 5  2423    1    0.926237     0.048306  0.052153    0.025457   39
# 6  2657    1    0.879856     0.066557  0.075645    0.053587   30
# 7  2478    1    0.936245     0.032811  0.035045    0.030944   54
# 8  2572    0    0.640527     0.307299  0.479759    0.052174   74
# 9  2619    0    0.898144     0.075223  0.083754    0.026633   80

# %%
plt.hist(df['age'], bins=80)
plt.tight_layout()
plt.show()

# %%
# plt.plot(df['age'], df['fluid_ratio'])
fig = plt.figure()
plt.bar(df['age'], df['fluid_ratio'])
plt.tight_layout()
plt.show()
fig.savefig('data/age_fluid_ratio.png', dpi=300)

# %%
plt.bar(df['age'], df['mass_ratio'])
plt.tight_layout()
plt.show()

# %%
plt.bar(df['age'], df['calc_ratio'])
plt.tight_layout()
plt.show()
